# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\User\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\User\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\User\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(loss=tf.keras.losses.categorical_crossentropy, optimizer=Adam(), metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size=128, epochs=50, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\User\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\User\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 469/469 [==============================] - 37s 77ms/step - loss: 0.2339 - accuracy: 0.9290 - val_loss: 0.0608 - val_accuracy: 0.9802
# Epoch 2/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0845 - accuracy: 0.9756 - val_loss: 0.0405 - val_accuracy: 0.9866
# Epoch 3/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0606 - accuracy: 0.9812 - val_loss: 0.0337 - val_accuracy: 0.9896
# Epoch 4/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0521 - accuracy: 0.9841 - val_loss: 0.0291 - val_accuracy: 0.9903
# Epoch 5/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0444 - accuracy: 0.9857 - val_loss: 0.0295 - val_accuracy: 0.9893
# Epoch 6/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0398 - accuracy: 0.9872 - val_loss: 0.0321 - val_accuracy: 0.9913
# Epoch 7/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0343 - accuracy: 0.9892 - val_loss: 0.0326 - val_accuracy: 0.9895
# Epoch 8/50
# 469/469 [==============================] - 32s 67ms/step - loss: 0.0313 - accuracy: 0.9902 - val_loss: 0.0339 - val_accuracy: 0.9894
# Epoch 9/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.0271 - accuracy: 0.9911 - val_loss: 0.0261 - val_accuracy: 0.9914
# Epoch 10/50
# 469/469 [==============================] - 38s 82ms/step - loss: 0.0246 - accuracy: 0.9920 - val_loss: 0.0301 - val_accuracy: 0.9905
# Epoch 11/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0233 - accuracy: 0.9923 - val_loss: 0.0301 - val_accuracy: 0.9920
# Epoch 12/50
# 469/469 [==============================] - 33s 69ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.0293 - val_accuracy: 0.9919
# Epoch 13/50
# 469/469 [==============================] - 40s 84ms/step - loss: 0.0211 - accuracy: 0.9927 - val_loss: 0.0336 - val_accuracy: 0.9914
# Epoch 14/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0344 - val_accuracy: 0.9909
# Epoch 15/50
# 469/469 [==============================] - 40s 85ms/step - loss: 0.0183 - accuracy: 0.9940 - val_loss: 0.0312 - val_accuracy: 0.9918
# Epoch 16/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0171 - accuracy: 0.9938 - val_loss: 0.0312 - val_accuracy: 0.9919
# Epoch 17/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.0318 - val_accuracy: 0.9922
# Epoch 18/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.0310 - val_accuracy: 0.9925
# Epoch 19/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0340 - val_accuracy: 0.9925
# Epoch 20/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0130 - accuracy: 0.9957 - val_loss: 0.0325 - val_accuracy: 0.9921
# Epoch 21/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0316 - val_accuracy: 0.9924
# Epoch 22/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0140 - accuracy: 0.9956 - val_loss: 0.0309 - val_accuracy: 0.9935
# Epoch 23/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0317 - val_accuracy: 0.9923
# Epoch 24/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.0323 - val_accuracy: 0.9929
# Epoch 25/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.0328 - val_accuracy: 0.9930
# Epoch 26/50
# 469/469 [==============================] - 35s 74ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0377 - val_accuracy: 0.9914
# Epoch 27/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 0.0329 - val_accuracy: 0.9929
# Epoch 28/50
# 469/469 [==============================] - 39s 82ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0366 - val_accuracy: 0.9929
# Epoch 29/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0338 - val_accuracy: 0.9935
# Epoch 30/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0337 - val_accuracy: 0.9931
# Epoch 31/50
# 469/469 [==============================] - 32s 67ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0393 - val_accuracy: 0.9929
# Epoch 32/50
# 469/469 [==============================] - 35s 75ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.0348 - val_accuracy: 0.9931
# Epoch 33/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0369 - val_accuracy: 0.9928
# Epoch 34/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0342 - val_accuracy: 0.9931
# Epoch 35/50
# 469/469 [==============================] - 35s 75ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.0340 - val_accuracy: 0.9924
# Epoch 36/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0395 - val_accuracy: 0.9924
# Epoch 37/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.0348 - val_accuracy: 0.9938
# Epoch 38/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0320 - val_accuracy: 0.9940
# Epoch 39/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0350 - val_accuracy: 0.9931
# Epoch 40/50
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0347 - val_accuracy: 0.9939
# Epoch 41/50
# 469/469 [==============================] - 39s 83ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0356 - val_accuracy: 0.9938
# Epoch 42/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0367 - val_accuracy: 0.9930
# Epoch 43/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0344 - val_accuracy: 0.9930
# Epoch 44/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0393 - val_accuracy: 0.9921
# Epoch 45/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0448 - val_accuracy: 0.9925
# Epoch 46/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0382 - val_accuracy: 0.9930
# Epoch 47/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0406 - val_accuracy: 0.9931
# Epoch 48/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0362 - val_accuracy: 0.9928
# Epoch 49/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0412 - val_accuracy: 0.9930
# Epoch 50/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0376 - val_accuracy: 0.9937

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.03755969554185867
# Test accuracy: 0.9937000274658203

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tensorflow.keras.utils import to_categorical

# %%
y_test_classes = np.argmax(y_test, axis=1)
y_pred_probabilities = model.predict(x_test)
y_pred_classes = np.argmax(y_pred_probabilities, axis=-1)
# Out:
# 313/313 [==============================] - 2s 6ms/step

# %%
cm = confusion_matrix(y_test_classes, y_pred_classes)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
y_test_binary = to_categorical(y_test_classes, num_classes=10)
for i in range(10):
    fpr[i], tpr[i], _ = roc_curve(y_test_binary[:, i], y_pred_probabilities[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
plt.figure()
for i in range(10):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'.format(i, roc_auc[i]))
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
